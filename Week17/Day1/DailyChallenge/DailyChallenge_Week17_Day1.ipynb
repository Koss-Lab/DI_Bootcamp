# %%
initial_prompt = (
    "## Role "
    "You are a learning content writer for internal employee communications. "
    "## Task "
    "Rewrite the policy text provided below for an internal newsletter. "
    "## Instructions "
    "Paraphrase the content using a friendly and clear tone. "
    "Organize the information using bullet points only. "
    "Do not use direct quotations from the original text. "
    "## Constraints "
    "The output must stay under 75 words total. "
    "Do not add any information that is not present in the input text. "
    "## Input Text "
    "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. "
    "Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."
)
initial_prompt
# Out:
# '## Role You are a learning content writer for internal employee communications. ## Task Rewrite the policy text provided below for an internal newsletter. ## Instructions Paraphrase the content using a friendly and clear tone. Organize the information using bullet points only. Do not use direct quotations from the original text. ## Constraints The output must stay under 75 words total. Do not add any information that is not present in the input text. ## Input Text Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.'

# %%
evaluation = {
    "relevance": "The output stays aligned with the original remote access security requirements.",
    "clarity": "The message is simplified and understandable for non technical employees.",
    "structure": "Information is clearly organized into bullet points.",
    "tone": "Language is friendly and appropriate for internal communication.",
    "length": "The output remains under the 75 word limit.",
    "factual_accuracy": "No security rules were removed or fabricated."
}
evaluation
# Out:
# {'relevance': 'The output stays aligned with the original remote access security requirements.',
#  'clarity': 'The message is simplified and understandable for non technical employees.',
#  'structure': 'Information is clearly organized into bullet points.',
#  'tone': 'Language is friendly and appropriate for internal communication.',
#  'length': 'The output remains under the 75 word limit.',
#  'factual_accuracy': 'No security rules were removed or fabricated.'}

# %%
anti_hallucination_prompt = (
    "## Role "
    "You are a learning content writer for internal employee communications. "
    "## Task "
    "Paraphrase the policy text provided below. "
    "## Strict Rules "
    "Only paraphrase the content in the input text. "
    "Do not add new recommendations technologies or policy terms. "
    "Do not remove any security requirement mentioned. "
    "## Format and Tone "
    "Use bullet points and a friendly clear tone. "
    "## Constraints "
    "Maximum 75 words total. "
    "## Input Text "
    "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. "
    "Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."
)
anti_hallucination_prompt
# Out:
# '## Role You are a learning content writer for internal employee communications. ## Task Paraphrase the policy text provided below. ## Strict Rules Only paraphrase the content in the input text. Do not add new recommendations technologies or policy terms. Do not remove any security requirement mentioned. ## Format and Tone Use bullet points and a friendly clear tone. ## Constraints Maximum 75 words total. ## Input Text Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.'

# %%
intern_prompt = (
    "## Role "
    "You are explaining company security rules to a junior intern. "
    "## Task "
    "Paraphrase the policy text below using very simple language. "
    "## Audience "
    "Assume the reader has no technical background. "
    "## Instructions "
    "Use short phrases and plain words. "
    "Avoid corporate legal or technical jargon. "
    "Use no more than 4 bullet points. "
    "## Tone "
    "Keep the tone supportive clear and informative. "
    "## Input Text "
    "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. "
    "Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."
)
intern_prompt
# Out:
# '## Role You are explaining company security rules to a junior intern. ## Task Paraphrase the policy text below using very simple language. ## Audience Assume the reader has no technical background. ## Instructions Use short phrases and plain words. Avoid corporate legal or technical jargon. Use no more than 4 bullet points. ## Tone Keep the tone supportive clear and informative. ## Input Text Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.'

# %%
quote_prompt = (
    "## Role "
    "You are preparing internal security communications. "
    "## Task "
    "Extract one direct quote from the policy text below that best represents the core security rule. "
    "## Rules "
    "Use the exact wording from the original text. "
    "Do not paraphrase or modify the sentence. "
    "Return only one quote. "
    "## Input Text "
    "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. "
    "Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."
)
quote_prompt
# Out:
# '## Role You are preparing internal security communications. ## Task Extract one direct quote from the policy text below that best represents the core security rule. ## Rules Use the exact wording from the original text. Do not paraphrase or modify the sentence. Return only one quote. ## Input Text Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.'

# %%
quote_analysis = {
    "when_quoting_is_better": "Quoting is more appropriate for official policy announcements compliance reminders or legal acknowledgements.",
    "quoting_risks": "Quoting can be risky when the language is too technical or intimidating for the audience or when context is missing."
}
quote_analysis
# Out:
# {'when_quoting_is_better': 'Quoting is more appropriate for official policy announcements compliance reminders or legal acknowledgements.',
#  'quoting_risks': 'Quoting can be risky when the language is too technical or intimidating for the audience or when context is missing.'}
