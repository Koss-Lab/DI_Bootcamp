# %% [markdown]
# # Exercises XP: Minimal MCP over STDIO (Student)
#
# Build a tiny MCP server and client that talk over STDIO. This code is supposed to be executed in a local jupyter notebook not Colab's notebook.

# %% [markdown]
# ## What you'll learn
# - How MCP structures hosts/clients/servers and why STDIO is great locally.
# - How to register a tool (action) and a resource (read-only context) on a server.
# - How to write a client that initializes, lists, and invokes those features.

# %% [markdown]
# ## Setup
# Run the install cell, then restart the runtime if Colab asks. Python 3.10+ required.

# %%
# Install MCP CLI + SDK
#%pip install -qU "mcp[cli]"
#!pip install -U "mcp[cli]"
# Out:
# Requirement already satisfied: mcp[cli] in /usr/local/lib/python3.12/dist-packages (1.25.0)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (2.12.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (2.12.3)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (3.0.4)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.38.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (1.2.1)
# Requirement already satisfied: typer>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from mcp[cli]) (0.20.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=4.5->mcp[cli]) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.1->mcp[cli]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.1->mcp[cli]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.1->mcp[cli]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp[cli]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp[cli]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp[cli]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp[cli]) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->mcp[cli]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->mcp[cli]) (2.41.4)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp[cli]) (43.0.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.16.0->mcp[cli]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.16.0->mcp[cli]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.16.0->mcp[cli]) (13.9.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.16.0->mcp[cli]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.16.0->mcp[cli]) (2.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp[cli]) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.16.0->mcp[cli]) (0.1.2)

# %%
# Quick verify
# !python --version
# !mcp --help | head -n 5
# Out:
# Python 3.12.12
#
#  Usage: mcp [OPTIONS] COMMAND [ARGS]...
#
#  MCP development tools

# %% [markdown]
# ## A. Server (server.py)
# Create a small MCP server named "Demo" with:
# - Tool `add(a: int, b: int) -> int` returning the sum.
# - Resource template `greeting://{name}` returning "Hello, {name}!".
# - Start the STDIO loop in `__main__`.

# %%
# %%writefile server.py
from mcp.server.fastmcp import FastMCP

# Create MCP server
mcp = FastMCP("Demo")

@mcp.tool()
def add(a: int, b: int) -> int:
    """Return the sum of two integers."""
    return a + b

@mcp.resource("greeting://{name}")
def greet(name: str) -> str:
    """Return a greeting for the given name."""
    return f"Hello, {name}!"

if __name__ == "__main__":
    # Start the server loop over STDIO
    mcp.run()
# Out:
# Overwriting server.py

# %% [markdown]
# ## B. Client (client.py)
# Write a client that:
# 1) Spawns the server via STDIO using the MCP CLI.
# 2) Initializes a session.
# 3) Lists resources and tools, printing their names.
# 4) Reads `greeting://hello` and prints it.
# 5) Calls tool `add` with a=1, b=7 and prints the result.

# %%
# %%writefile client.py
import asyncio
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

# Parameters to spawn the server over STDIO
server_params = StdioServerParameters(
    command="mcp",
    args=["run", "server.py"],
    env=None
)

def extract_content(payload):
    """Best-effort to pull text from MCP responses."""
    if hasattr(payload, "contents"):
        contents = payload.contents
        if contents:
            first = contents[0]
            if hasattr(first, "text"):
                return first.text
            if isinstance(first, dict) and "text" in first:
                return first["text"]
            return str(first)
    if hasattr(payload, "content"):
        return payload.content
    return str(payload)

async def run():
    async with stdio_client(server_params) as (read, write):
        async with ClientSession(read, write) as session:
            # Initialize MCP session
            await session.initialize()

            # List resources
            resources = await session.list_resources()
            print("Resources:")
            for r in resources.resources:
                print("-", r.uri)

            # List tools
            tools = await session.list_tools()
            print("\nTools:")
            for t in tools.tools:
                print("-", t.name)

            # Read greeting://hello
            greeting = await session.read_resource("greeting://hello")
            print("\nGreeting result:")
            print(extract_content(greeting))

            # Call add tool
            result = await session.call_tool(
                "add",
                {"a": 1, "b": 7}
            )
            print("\nAdd tool result:")
            print(extract_content(result))

if __name__ == "__main__":
    asyncio.run(run())
# Out:
# Overwriting client.py

# %% [markdown]
# ## C. Run
# One terminal (client spawns server):
# ```
# python client.py
# ```
#
# Or two terminals:
# ```
# mcp run server.py
# python client.py
# ```
#
# In Colab, run the next cell (client will spawn the server automatically).

# %%
# Run the client (spawns the server over STDIO)
# !python client.py
# Out:
# [12/21/25 16:47:37] INFO     Processing request of type            ]8;id=891443;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=373917;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py#713\713]8;;\
#                              ListResourcesRequest
# Resources:
#                     INFO     Processing request of type            ]8;id=749235;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=982589;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py#713\713]8;;\
#                              ListToolsRequest
#
# Tools:
# - add
#                     INFO     Processing request of type            ]8;id=735523;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=428431;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py#713\713]8;;\
#                              ReadResourceRequest
#
# Greeting result:
# Hello, hello!
#                     INFO     Processing request of type            ]8;id=778517;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py\server.py]8;;\:]8;id=336467;file:///usr/local/lib/python3.12/dist-packages/mcp/server/lowlevel/server.py#713\713]8;;\
#                              CallToolRequest
#
# Add tool result:
# [TextContent(type='text', text='8', annotations=None, meta=None)]

# %% [markdown]
# ## Troubleshooting
# - `mcp: command not found` ? rerun the install cell or restart runtime.
# - Connection closed ? open a second terminal and run `mcp run server.py` to check server errors.
# - Type errors ? ensure JSON args are ints for `add`.
