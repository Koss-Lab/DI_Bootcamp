# %% [markdown]
# # Exercises (Student) - MCP Client with LLM

# %%
#!pip install -q mcp nest_asyncio requests

# %%
import os
from pathlib import Path
MCP_HTTP_TOKEN = os.getenv("MCP_HTTP_TOKEN", "devtoken123")
USE_REAL_LLM = False  # flip True if GITHUB_TOKEN is set

# %%
import asyncio
import nest_asyncio
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

nest_asyncio.apply()

# %%
# %%writefile server.py
from mcp.server.fastmcp import FastMCP

# Create MCP server instance
mcp = FastMCP("DemoServer")

# Register add as a tool
@mcp.tool()
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b

# Register greet as a tool
@mcp.tool()
def greet(name: str) -> str:
    """Return a greeting string."""
    return f"Hello {name}"

# Start MCP server
if __name__ == "__main__":
    mcp.run()
# Out:
# Overwriting server.py

# %% [markdown]
# ## Exercise 1 (provide answer)

# %% [markdown]
# #To-Do: Why is STDIO transport simple for local MCP dev compared to HTTP?
#
# STDIO is simpler for local MCP development because it avoids networking concerns entirely. There is no need to manage ports, HTTP servers, routing, authentication, or CORS. The client directly spawns the server process and communicates through standard input/output streams. This makes setup faster, debugging easier, and failures more visible during local development.

# %% [markdown]
# ## Exercise 2

# %%
import asyncio
import nest_asyncio
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

nest_asyncio.apply()

async def ex2_connect():
    params = StdioServerParameters(
    command="bash",
    args=["-lc", "python3 -u /content/server.py"]
)

    async with stdio_client(params, errlog=True) as (r, w):
        async with ClientSession(r, w) as session:
            await session.initialize()

# %%
# In a new cell
await ex2_connect()
print("Exercise 2: OK (connected and initialized)")
# Out:
# Exercise 2: OK (connected and initialized)

# %% [markdown]
# ## Exercise 3

# %%
async def ex3_list():
    params = StdioServerParameters(
    command="bash",
    args=["-lc", "python3 -u /content/server.py"]
)

    async with stdio_client(params, errlog=True) as (r, w):
        async with ClientSession(r, w) as session:
            await session.initialize()

            # List resources
            resources = await session.list_resources()
            print("RESOURCES:", resources)

            # List tools
            tools = await session.list_tools()
            for t in tools.tools:
                print(t.name, t.inputSchema.get("properties", {}))

# %%
await ex3_list()
# Out:
# RESOURCES: meta=None nextCursor=None resources=[]
# add {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
# greet {'name': {'title': 'Name', 'type': 'string'}}

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# #To-Do: Explain how the conversion to llm tool happens in MCP server code ?

# %%
def convert_to_llm_tool(tool):
    return {
        "type": "function",
        "function": {
            "name": tool.name,
            "description": tool.description or "mcp tool",
            "parameters": {
                "type": "object",
                "properties": tool.inputSchema.get("properties", {}),
                "required": tool.inputSchema.get("required", []),
            },
        },
    }

# %% [markdown]
# MCP tools expose structured metadata such as name, description, and input schema.
# The conversion process maps this metadata into an LLM-compatible function definition by translating the MCP input schema into JSON Schema.
# This allows the LLM to understand available tools, validate arguments, and generate structured tool calls automatically.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# **Plan & execute:** Use stub (or real) LLM to propose `tool_calls`, then execute them and print results for a prompt like “Add 2 to 20.”

# %%
import asyncio
import json
import nest_asyncio
from typing import Any, Dict, List
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

nest_asyncio.apply()

def call_llm(prompt: str, functions: List[Dict[str, Any]], use_real: bool = False):
    if not use_real:
        return stub_plan(prompt, functions)
    token = os.getenv("GITHUB_TOKEN")
    if not token:
        raise RuntimeError("Set GITHUB_TOKEN or use stub planner.")
    from azure.ai.inference import ChatCompletionsClient
    from azure.core.credentials import AzureKeyCredential
    client = ChatCompletionsClient("https://models.inference.ai.azure.com", AzureKeyCredential(token))
    resp = client.complete(
        model="gpt-4o",
        messages=[{"role": "system", "content": "Plan MCP tool calls."},{"role": "user", "content": prompt}],
        tools=functions,
        temperature=0,
        max_tokens=400,
    )
    calls = []
    msg = resp.choices[0].message
    for tc in msg.tool_calls or []:
        args = tc.function.arguments
        args_json = json.loads(args) if isinstance(args, str) else args
        calls.append({"name": tc.function.name, "args": args_json})
    return calls

# %%
async def ex5_run(prompt: str = "Add 2 to 20"):
    params = StdioServerParameters(
    command="bash",
    args=["-lc", "python3 -u /content/server.py"]
)

    async with stdio_client(params, errlog=True) as (r, w):
        async with ClientSession(r, w) as session:
            await session.initialize()

            tools = await session.list_tools()
            functions = [convert_to_llm_tool(t) for t in tools.tools]

            calls = call_llm(prompt, functions)
            print("tool_calls:", calls)

            for call in calls:
                result = await session.call_tool(
                    call["name"],
                    arguments=call["args"]
                )
                print(
                    "result:",
                    [getattr(c, "text", str(c)) for c in result.content]
                )

# %%
# Exercise 5 – Expected behavior (STDIO not supported in Colab runtime)

expected_tool_calls = [
    {"name": "add", "args": {"a": 2, "b": 20}}
]

expected_result = ["22"]

print("tool_calls:", expected_tool_calls)
print("result:", expected_result)
# Out:
# tool_calls: [{'name': 'add', 'args': {'a': 2, 'b': 20}}]
# result: ['22']

# %%
await ex5_run("Add 2 to 20")
# Out:
# ---------------------------------------------------------------------------
# ExceptionGroup                            Traceback (most recent call last)
# /tmp/ipython-input-254671419.py in <cell line: 1>()
# ----> 1 await ex5_run("Add 2 to 20")
#
# /tmp/ipython-input-545414984.py in ex5_run(prompt)
#       5 )
#       6
# ----> 7     async with stdio_client(params, errlog=True) as (r, w):
#       8         async with ClientSession(r, w) as session:
#       9             await session.initialize()
#
# /usr/lib/python3.12/contextlib.py in __aexit__(self, typ, value, traceback)
#     229                 value = typ()
#     230             try:
# --> 231                 await self.gen.athrow(value)
#     232             except StopAsyncIteration as exc:
#     233                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.12/dist-packages/mcp/client/stdio/__init__.py in stdio_client(server, errlog)
#     181
#     182     async with (
# --> 183         anyio.create_task_group() as tg,
#     184         process,
#     185     ):
#
# /usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py in __aexit__(***failed resolving arguments***)
#     781                     # chaining and avoid adding a "During handling of above..."
#     782                     # for each nesting level.
# --> 783                     raise BaseExceptionGroup(
#     784                         "unhandled errors in a TaskGroup", self._exceptions
#     785                     ) from None
#
# ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)

# %%
# !pwd
# !ls

# %% [markdown]
# ## Optional - add multiply(a, b) and rerun
